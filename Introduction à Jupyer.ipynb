# %% [markdown]
# ## Interagir avec les cellules
#
# ### Types de cellules
# <img src="attachment:b7cd3a57-fb93-4c39-95bf-6443383e3707.png" width="500"/>
#
# * `Markdown`: Pour le texte
# * `Code`: Pour le code
#
# ### Modifier une cellule
#
# * Pour les cellules `markdown` : Double cliquer
# * Pour les cellules `code` : Cliquer
#
# ### Executer une cellule
#
# 1. Cliquer sur la cellule
# 2. Appuyer sur le clavier : `shift+return`

# %%
# Si tu roules cette cellule, TADA!! La réponse apparaitra en dessous!
# Si tu veux écrire du texte dans les cellules de code, utilise ce symbole "#" au début de la ligne comme ici!
def additionner(a, b):
    return a+b
    
additionner(3, 4)
# Out:
# 7

# %% [markdown]
# ### Actions d'une cellule
#
# <img src="attachment:d4a3303c-8542-46a0-babf-5321711ca60b.png" width="200"/>
#
# Dans le coin droit supérieur, il possible
# * de bouger une cellule avec les flèches
# * d'ajouter une cellule avec les +
#   * avant ou après la cellule courante
# * de les effacer avec la poubelle
